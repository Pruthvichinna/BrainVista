# %% [markdown]
# **FINAL CODES**

# %%
normal_path = "/kaggle/input/brains/Brain_Data_Organised/Normal"
stroke_path = "/kaggle/input/brains/Brain_Data_Organised/Stroke"

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import torch
import torch.nn as nn
import torchvision.models as models
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.nasnet import NASNetLarge
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# Out:
# 2025-05-22 05:00:39.389855: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747890039.597487      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747890039.656553      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Flatten, Dense, concatenate
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# === 1. Load and preprocess images ===
def load_and_preprocess_images(normal_path, stroke_path, target_size=(227, 227)):
    all_images, all_labels = [], []

    for img_name in os.listdir(normal_path):
        img_path = os.path.join(normal_path, img_name)
        img = image.load_img(img_path, target_size=target_size)
        img = image.img_to_array(img)
        all_images.append(img)
        all_labels.append(0)

    for img_name in os.listdir(stroke_path):
        img_path = os.path.join(stroke_path, img_name)
        img = image.load_img(img_path, target_size=target_size)
        img = image.img_to_array(img)
        all_images.append(img)
        all_labels.append(1)

    return np.array(all_images), np.array(all_labels)

normal_path = "/kaggle/input/brains/Brain_Data_Organised/Normal"
stroke_path = "/kaggle/input/brains/Brain_Data_Organised/Stroke"

all_images, all_labels = load_and_preprocess_images(normal_path, stroke_path)
encoded_labels = to_categorical(all_labels)

# === 2. Split the dataset ===
X_train, X_test, y_train, y_test = train_test_split(all_images, encoded_labels, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# === 3. Custom CNN Architectures ===
def create_alexnet(input_shape=(227, 227, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(96, (11, 11), strides=4, activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=2)(x)
    x = Conv2D(256, (5, 5), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=2)(x)
    x = Conv2D(384, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(384, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(256, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=2)(x)
    x = Flatten()(x)
    x = Dense(4096, activation='relu')(x)
    x = Dense(4096, activation='relu')(x)
    return Model(inputs=inputs, outputs=x)

def create_custom_inceptionv3(input_shape=(227, 227, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2))(x)

    tower_1 = Conv2D(64, (1, 1), activation='relu', padding='same')(x)
    tower_1 = Conv2D(64, (3, 3), activation='relu', padding='same')(tower_1)

    tower_2 = Conv2D(64, (1, 1), activation='relu', padding='same')(x)
    tower_2 = Conv2D(64, (5, 5), activation='relu', padding='same')(tower_2)

    tower_3 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    tower_3 = Conv2D(64, (1, 1), activation='relu', padding='same')(tower_3)

    x = concatenate([tower_1, tower_2, tower_3], axis=-1)
    x = GlobalAveragePooling2D()(x)
    return Model(inputs, x)

def create_custom_vgg19(input_shape=(227, 227, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(inputs)
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(256, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(256, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    return Model(inputs, x)

def create_custom_nasnet(input_shape=(227, 227, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')(inputs)
    x = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)

    for _ in range(3):
        x1 = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
        x2 = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
        x = concatenate([x1, x2], axis=-1)

    x = GlobalAveragePooling2D()(x)
    return Model(inputs, x)

def create_shufflenet(input_shape=(227, 227, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(24, (3, 3), strides=2, padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=2, padding='same')(x)
    x = Conv2D(144, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(144, (3, 3), padding='same', activation='relu')(x)
    x = Conv2D(288, (1, 1), padding='same', activation='relu')(x)
    x = GlobalAveragePooling2D()(x)
    return Model(inputs=inputs, outputs=x)

# === 4. Preprocessing function ===
def preprocess_for_model(images):
    return (images / 255.0).astype('float32')

# === 5. Feature extraction ===
def extract_features(model, images, batch_size=32):
    processed_images = preprocess_for_model(images)
    return model.predict(processed_images, batch_size=batch_size, verbose=1)

# === 6. Instantiate models ===
alexnet_model = create_alexnet()
inception_model = create_custom_inceptionv3()
vgg19_model = create_custom_vgg19()
nasnet_model = create_custom_nasnet()
shufflenet_model = create_shufflenet()

# === 7. Extract features ===
print("Extracting features from AlexNet...")
alexnet_features = extract_features(alexnet_model, X_train)
print("Extracting features from InceptionV3...")
inception_features = extract_features(inception_model, X_train)
print("Extracting features from VGG19...")
vgg19_features = extract_features(vgg19_model, X_train)
print("Extracting features from NASNet...")
nasnet_features = extract_features(nasnet_model, X_train)
print("Extracting features from ShuffleNet...")
shufflenet_features = extract_features(shufflenet_model, X_train)

# === 8. Combine and display ===
combined_features = np.concatenate([
    alexnet_features,
    inception_features,
    vgg19_features,
    nasnet_features,
    shufflenet_features
], axis=1)

print(f"\nShape of combined features: {combined_features.shape}")
# Out:
# I0000 00:00:1747890085.620335      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Extracting features from AlexNet...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747890090.027189      90 service.cc:148] XLA service 0x7b10440036a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747890090.027931      90 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747890090.128460      90 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 18/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# I0000 00:00:1747890091.974584      90 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step
# Extracting features from InceptionV3...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step
# Extracting features from VGG19...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 16s 196ms/step
# Extracting features from NASNet...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step
# Extracting features from ShuffleNet...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
#
# Shape of combined features: (1400, 29792)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import random
import os

# Optional: for reproducibility
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Assume combined_features and y_train from your previous code
X_ga_train, X_ga_val, y_ga_train, y_ga_val = train_test_split(
    combined_features, y_train, test_size=0.2, random_state=seed
)

# GA parameters
num_features = combined_features.shape[1]
population_size = 20
num_generations = 10
crossover_rate = 0.8
mutation_rate = 0.02
num_parents = 10

# Initialize population (binary chromosomes)
def initialize_population():
    return np.random.randint(0, 2, size=(population_size, num_features))

# Fitness function using a small NN
def fitness(chromosome):
    selected_indices = np.where(chromosome == 1)[0]
    if len(selected_indices) == 0:
        return 0  # avoid empty feature sets

    X_sel_train = X_ga_train[:, selected_indices]
    X_sel_val = X_ga_val[:, selected_indices]

    model = Sequential([
        Input(shape=(X_sel_train.shape[1],)),
        Dense(128, activation='relu'),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(2, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_sel_train, y_ga_train, epochs=10, batch_size=32, verbose=0)

    val_preds = model.predict(X_sel_val, verbose=0)
    acc = accuracy_score(np.argmax(y_ga_val, axis=1), np.argmax(val_preds, axis=1))
    return acc

# Select top-k parents
def select_parents(population, fitness_scores, k):
    idx = np.argsort(fitness_scores)[-k:]
    return population[idx]

# Single-point crossover
def crossover(parents):
    offspring = []
    while len(offspring) < population_size - len(parents):
        parent1, parent2 = random.sample(list(parents), 2)
        if np.random.rand() < crossover_rate:
            point = random.randint(1, num_features - 2)
            child = np.concatenate([parent1[:point], parent2[point:]])
        else:
            child = parent1.copy()
        offspring.append(child)
    return np.array(offspring)

# Mutation (bit flip)
def mutate(offspring):
    for child in offspring:
        for i in range(num_features):
            if np.random.rand() < mutation_rate:
                child[i] = 1 - child[i]
    return offspring

# Run GA
population = initialize_population()

for gen in range(num_generations):
    print(f"\n Generation {gen+1}/{num_generations}")

    fitness_scores = []
    for i, chromo in enumerate(population):
        acc = fitness(chromo)
        fitness_scores.append(acc)
        print(f"Chromosome {i+1}/{population_size} → Accuracy: {acc:.4f}")

    best_idx = np.argmax(fitness_scores)
    print(f" Best Accuracy this Gen: {fitness_scores[best_idx]:.4f}")

    parents = select_parents(population, fitness_scores, num_parents)
    offspring = crossover(parents)
    offspring = mutate(offspring)
    population = np.vstack((parents, offspring))

# Final best solution
final_fitness_scores = [fitness(chromo) for chromo in population]
best_chromosome = population[np.argmax(final_fitness_scores)]
selected_features = np.where(best_chromosome == 1)[0]

print(f"\n Total selected features: {len(selected_features)}")
print(f" Selected feature indices: {selected_features}")
# Out:
#  Generation 1/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6393
# Chromosome 3/20 → Accuracy: 0.6393
# Chromosome 4/20 → Accuracy: 0.6429
# Chromosome 5/20 → Accuracy: 0.6464
# Chromosome 6/20 → Accuracy: 0.6429
# Chromosome 7/20 → Accuracy: 0.6429
# Chromosome 8/20 → Accuracy: 0.6464
# Chromosome 9/20 → Accuracy: 0.6500
# Chromosome 10/20 → Accuracy: 0.6464
# Chromosome 11/20 → Accuracy: 0.6429
# Chromosome 12/20 → Accuracy: 0.6500
# Chromosome 13/20 → Accuracy: 0.6393
# Chromosome 14/20 → Accuracy: 0.6464
# Chromosome 15/20 → Accuracy: 0.6393
# Chromosome 16/20 → Accuracy: 0.6500
# Chromosome 17/20 → Accuracy: 0.6429
# Chromosome 18/20 → Accuracy: 0.6357
# Chromosome 19/20 → Accuracy: 0.6464
# Chromosome 20/20 → Accuracy: 0.6536
#  Best Accuracy this Gen: 0.6536
#
#  Generation 2/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6464
# Chromosome 3/20 → Accuracy: 0.6500
# Chromosome 4/20 → Accuracy: 0.6429
# Chromosome 5/20 → Accuracy: 0.6429
# Chromosome 6/20 → Accuracy: 0.6357
# Chromosome 7/20 → Accuracy: 0.6500
# Chromosome 8/20 → Accuracy: 0.6429
# Chromosome 9/20 → Accuracy: 0.6357
# Chromosome 10/20 → Accuracy: 0.6429
# Chromosome 11/20 → Accuracy: 0.6500
# Chromosome 12/20 → Accuracy: 0.6429
# Chromosome 13/20 → Accuracy: 0.6250
# Chromosome 14/20 → Accuracy: 0.6464
# Chromosome 15/20 → Accuracy: 0.6393
# Chromosome 16/20 → Accuracy: 0.6357
# Chromosome 17/20 → Accuracy: 0.6429
# Chromosome 18/20 → Accuracy: 0.6464
# Chromosome 19/20 → Accuracy: 0.6464
# Chromosome 20/20 → Accuracy: 0.6464
#  Best Accuracy this Gen: 0.6500
#
#  Generation 3/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6393
# Chromosome 3/20 → Accuracy: 0.6357
# Chromosome 4/20 → Accuracy: 0.6393
# Chromosome 5/20 → Accuracy: 0.6464
# Chromosome 6/20 → Accuracy: 0.6393
# Chromosome 7/20 → Accuracy: 0.6393
# Chromosome 8/20 → Accuracy: 0.6393
# Chromosome 9/20 → Accuracy: 0.6464
# Chromosome 10/20 → Accuracy: 0.6393
# Chromosome 11/20 → Accuracy: 0.6393
# Chromosome 12/20 → Accuracy: 0.6464
# Chromosome 13/20 → Accuracy: 0.6464
# Chromosome 14/20 → Accuracy: 0.6393
# Chromosome 15/20 → Accuracy: 0.6464
# Chromosome 16/20 → Accuracy: 0.6429
# Chromosome 17/20 → Accuracy: 0.6464
# Chromosome 18/20 → Accuracy: 0.6429
# Chromosome 19/20 → Accuracy: 0.6464
# Chromosome 20/20 → Accuracy: 0.6393
#  Best Accuracy this Gen: 0.6464
#
#  Generation 4/10
# Chromosome 1/20 → Accuracy: 0.6500
# Chromosome 2/20 → Accuracy: 0.6393
# Chromosome 3/20 → Accuracy: 0.6464
# Chromosome 4/20 → Accuracy: 0.6357
# Chromosome 5/20 → Accuracy: 0.6429
# Chromosome 6/20 → Accuracy: 0.6429
# Chromosome 7/20 → Accuracy: 0.6393
# Chromosome 8/20 → Accuracy: 0.6429
# Chromosome 9/20 → Accuracy: 0.6643
# Chromosome 10/20 → Accuracy: 0.6464
# Chromosome 11/20 → Accuracy: 0.6321
# Chromosome 12/20 → Accuracy: 0.6500
# Chromosome 13/20 → Accuracy: 0.6357
# Chromosome 14/20 → Accuracy: 0.6464
# Chromosome 15/20 → Accuracy: 0.6464
# Chromosome 16/20 → Accuracy: 0.6393
# Chromosome 17/20 → Accuracy: 0.6321
# Chromosome 18/20 → Accuracy: 0.6429
# Chromosome 19/20 → Accuracy: 0.6464
# Chromosome 20/20 → Accuracy: 0.6429
#  Best Accuracy this Gen: 0.6643
#
#  Generation 5/10
# Chromosome 1/20 → Accuracy: 0.6536
# Chromosome 2/20 → Accuracy: 0.6429
# Chromosome 3/20 → Accuracy: 0.6464
# Chromosome 4/20 → Accuracy: 0.6393
# Chromosome 5/20 → Accuracy: 0.6464
# Chromosome 6/20 → Accuracy: 0.6571
# Chromosome 7/20 → Accuracy: 0.6464
# Chromosome 8/20 → Accuracy: 0.6393
# Chromosome 9/20 → Accuracy: 0.6286
# Chromosome 10/20 → Accuracy: 0.6429
# Chromosome 11/20 → Accuracy: 0.6464
# Chromosome 12/20 → Accuracy: 0.6429
# Chromosome 13/20 → Accuracy: 0.6429
# Chromosome 14/20 → Accuracy: 0.6429
# Chromosome 15/20 → Accuracy: 0.6429
# Chromosome 16/20 → Accuracy: 0.6321
# Chromosome 17/20 → Accuracy: 0.6357
# Chromosome 18/20 → Accuracy: 0.6429
# Chromosome 19/20 → Accuracy: 0.6429
# Chromosome 20/20 → Accuracy: 0.6464
#  Best Accuracy this Gen: 0.6571
#
#  Generation 6/10
# Chromosome 1/20 → Accuracy: 0.6429
# Chromosome 2/20 → Accuracy: 0.6536
# Chromosome 3/20 → Accuracy: 0.6429
# Chromosome 4/20 → Accuracy: 0.6357
# Chromosome 5/20 → Accuracy: 0.6536
# Chromosome 6/20 → Accuracy: 0.6393
# Chromosome 7/20 → Accuracy: 0.6429
# Chromosome 8/20 → Accuracy: 0.6464
# Chromosome 9/20 → Accuracy: 0.6536
# Chromosome 10/20 → Accuracy: 0.6429
# Chromosome 11/20 → Accuracy: 0.6357
# Chromosome 12/20 → Accuracy: 0.6500
# Chromosome 13/20 → Accuracy: 0.6464
# Chromosome 14/20 → Accuracy: 0.6357
# Chromosome 15/20 → Accuracy: 0.6500
# Chromosome 16/20 → Accuracy: 0.6429
# Chromosome 17/20 → Accuracy: 0.6393
# Chromosome 18/20 → Accuracy: 0.6464
# Chromosome 19/20 → Accuracy: 0.6464
# Chromosome 20/20 → Accuracy: 0.6429
#  Best Accuracy this Gen: 0.6536
#
#  Generation 7/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6393
# Chromosome 3/20 → Accuracy: 0.6393
# Chromosome 4/20 → Accuracy: 0.6357
# Chromosome 5/20 → Accuracy: 0.6500
# Chromosome 6/20 → Accuracy: 0.6393
# Chromosome 7/20 → Accuracy: 0.6429
# Chromosome 8/20 → Accuracy: 0.6429
# Chromosome 9/20 → Accuracy: 0.6679
# Chromosome 10/20 → Accuracy: 0.6393
# Chromosome 11/20 → Accuracy: 0.6429
# Chromosome 12/20 → Accuracy: 0.6429
# Chromosome 13/20 → Accuracy: 0.6429
# Chromosome 14/20 → Accuracy: 0.6464
# Chromosome 15/20 → Accuracy: 0.6429
# Chromosome 16/20 → Accuracy: 0.6429
# Chromosome 17/20 → Accuracy: 0.6464
# Chromosome 18/20 → Accuracy: 0.6357
# Chromosome 19/20 → Accuracy: 0.6393
# Chromosome 20/20 → Accuracy: 0.6393
#  Best Accuracy this Gen: 0.6679
#
#  Generation 8/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6500
# Chromosome 3/20 → Accuracy: 0.6464
# Chromosome 4/20 → Accuracy: 0.6393
# Chromosome 5/20 → Accuracy: 0.6429
# Chromosome 6/20 → Accuracy: 0.6429
# Chromosome 7/20 → Accuracy: 0.6464
# Chromosome 8/20 → Accuracy: 0.6393
# Chromosome 9/20 → Accuracy: 0.6500
# Chromosome 10/20 → Accuracy: 0.6393
# Chromosome 11/20 → Accuracy: 0.6464
# Chromosome 12/20 → Accuracy: 0.6464
# Chromosome 13/20 → Accuracy: 0.6393
# Chromosome 14/20 → Accuracy: 0.6536
# Chromosome 15/20 → Accuracy: 0.6500
# Chromosome 16/20 → Accuracy: 0.6464
# Chromosome 17/20 → Accuracy: 0.6536
# Chromosome 18/20 → Accuracy: 0.6429
# Chromosome 19/20 → Accuracy: 0.6429
# Chromosome 20/20 → Accuracy: 0.6571
#  Best Accuracy this Gen: 0.6571
#
#  Generation 9/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6464
# Chromosome 3/20 → Accuracy: 0.6500
# Chromosome 4/20 → Accuracy: 0.6500
# Chromosome 5/20 → Accuracy: 0.6464
# Chromosome 6/20 → Accuracy: 0.6464
# Chromosome 7/20 → Accuracy: 0.6464
# Chromosome 8/20 → Accuracy: 0.6393
# Chromosome 9/20 → Accuracy: 0.6464
# Chromosome 10/20 → Accuracy: 0.6500
# Chromosome 11/20 → Accuracy: 0.6464
# Chromosome 12/20 → Accuracy: 0.6393
# Chromosome 13/20 → Accuracy: 0.6464
# Chromosome 14/20 → Accuracy: 0.6464
# Chromosome 15/20 → Accuracy: 0.6500
# Chromosome 16/20 → Accuracy: 0.6357
# Chromosome 17/20 → Accuracy: 0.6393
# Chromosome 18/20 → Accuracy: 0.6607
# Chromosome 19/20 → Accuracy: 0.6429
# Chromosome 20/20 → Accuracy: 0.6464
#  Best Accuracy this Gen: 0.6607
#
#  Generation 10/10
# Chromosome 1/20 → Accuracy: 0.6464
# Chromosome 2/20 → Accuracy: 0.6357
# Chromosome 3/20 → Accuracy: 0.6429
# Chromosome 4/20 → Accuracy: 0.6536
# Chromosome 5/20 → Accuracy: 0.6464
# Chromosome 6/20 → Accuracy: 0.6429
# Chromosome 7/20 → Accuracy: 0.6429
# Chromosome 8/20 → Accuracy: 0.6393
# Chromosome 9/20 → Accuracy: 0.6429
# Chromosome 10/20 → Accuracy: 0.6429
# Chromosome 11/20 → Accuracy: 0.6286
# Chromosome 12/20 → Accuracy: 0.6429
# Chromosome 13/20 → Accuracy: 0.6536
# Chromosome 14/20 → Accuracy: 0.6429
# Chromosome 15/20 → Accuracy: 0.6429
# Chromosome 16/20 → Accuracy: 0.6321
# Chromosome 17/20 → Accuracy: 0.6464
# Chromosome 18/20 → Accuracy: 0.6500
# Chromosome 19/20 → Accuracy: 0.6393
# Chromosome 20/20 → Accuracy: 0.6500
#  Best Accuracy this Gen: 0.6536
#
#  Total selected features: 15009
#  Selected feature indices: [    0     2     3 ... 29787 29788 29789]

# %%
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, roc_curve, auc
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import tensorflow.keras.backend as K

# === 1. Data Preparation ===
# Scale features
scaler = StandardScaler()
X_ga_train_scaled = scaler.fit_transform(X_ga_train[:, selected_features])
X_ga_val_scaled = scaler.transform(X_ga_val[:, selected_features])

# Reshape for LSTM [samples, timesteps=1, features]
X_train = X_ga_train_scaled.reshape(X_ga_train_scaled.shape[0], 1, X_ga_train_scaled.shape[1])
X_val = X_ga_val_scaled.reshape(X_ga_val_scaled.shape[0], 1, X_ga_val_scaled.shape[1])

# Class weights for imbalance
y_labels = np.argmax(y_ga_train, axis=1)
weights = class_weight.compute_class_weight(class_weight='balanced', 
                                          classes=np.unique(y_labels), 
                                          y=y_labels)
class_weights = dict(enumerate(weights))

# === 2. LSTM Model Architecture (Matching Paper) ===
def build_lstm_model(input_shape):
    inputs = Input(shape=input_shape)
    
    # LSTM Layer with 64 units (as in paper)
    x = LSTM(64, 
             return_sequences=False,
             kernel_regularizer=l2(0.01),
             recurrent_regularizer=l2(0.01))(inputs)
    x = Dropout(0.3)(x)  # 30% dropout as in paper
    x = BatchNormalization()(x)
    
    # Dense Layer with 64 units (as in paper)
    x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.2)(x)  # 20% dropout as in paper
    
    # Output layer
    outputs = Dense(2, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

model = build_lstm_model((1, X_train.shape[2]))

# === 3. Model Compilation ===
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    clipvalue=0.5  # Gradient clipping
)
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy', 
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)

# === 4. Callbacks ===
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True),
    ModelCheckpoint('best_lstm_model.keras', save_best_only=True, monitor='val_accuracy'),
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=1e-6)
]

# === 5. Model Training ===
history = model.fit(
    X_train, y_ga_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_ga_val),
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)

# === 6. Evaluation ===
val_probs = model.predict(X_val)
val_preds = np.argmax(val_probs, axis=1)
y_true = np.argmax(y_ga_val, axis=1)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, val_preds, digits=4))

# Calculate metrics
accuracy = accuracy_score(y_true, val_preds)
fpr, tpr, _ = roc_curve(y_true, val_probs[:, 1])
roc_auc = auc(fpr, tpr)

print(f"\nFinal Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"AUC: {roc_auc:.4f}")

# === 7. ROC Curve ===
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# === 8. Learning Curves ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.5028 - loss: 5.9423 - precision: 0.5028 - recall: 0.5028 - val_accuracy: 0.7071 - val_loss: 3.9210 - val_precision: 0.7071 - val_recall: 0.7071 - learning_rate: 0.0010
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6380 - loss: 3.6172 - precision: 0.6380 - recall: 0.6380 - val_accuracy: 0.7464 - val_loss: 2.6631 - val_precision: 0.7464 - val_recall: 0.7464 - learning_rate: 0.0010
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6676 - loss: 2.5245 - precision: 0.6676 - recall: 0.6676 - val_accuracy: 0.7071 - val_loss: 2.0869 - val_precision: 0.7071 - val_recall: 0.7071 - learning_rate: 0.0010
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7150 - loss: 2.0481 - precision: 0.7150 - recall: 0.7150 - val_accuracy: 0.7250 - val_loss: 1.8307 - val_precision: 0.7250 - val_recall: 0.7250 - learning_rate: 0.0010
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7226 - loss: 1.8071 - precision: 0.7226 - recall: 0.7226 - val_accuracy: 0.7393 - val_loss: 1.7381 - val_precision: 0.7393 - val_recall: 0.7393 - learning_rate: 0.0010
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7089 - loss: 1.7292 - precision: 0.7089 - recall: 0.7089 - val_accuracy: 0.7357 - val_loss: 1.6298 - val_precision: 0.7357 - val_recall: 0.7357 - learning_rate: 0.0010
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7253 - loss: 1.6360 - precision: 0.7253 - recall: 0.7253 - val_accuracy: 0.7321 - val_loss: 1.6006 - val_precision: 0.7321 - val_recall: 0.7321 - learning_rate: 0.0010
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7586 - loss: 1.5803 - precision: 0.7586 - recall: 0.7586 - val_accuracy: 0.7929 - val_loss: 1.4073 - val_precision: 0.7929 - val_recall: 0.7929 - learning_rate: 5.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8446 - loss: 1.3230 - precision: 0.8446 - recall: 0.8446 - val_accuracy: 0.8179 - val_loss: 1.2314 - val_precision: 0.8179 - val_recall: 0.8179 - learning_rate: 5.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8502 - loss: 1.1496 - precision: 0.8502 - recall: 0.8502 - val_accuracy: 0.8857 - val_loss: 1.0923 - val_precision: 0.8857 - val_recall: 0.8857 - learning_rate: 5.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8544 - loss: 1.0703 - precision: 0.8544 - recall: 0.8544 - val_accuracy: 0.8679 - val_loss: 1.0387 - val_precision: 0.8679 - val_recall: 0.8679 - learning_rate: 5.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8711 - loss: 1.0054 - precision: 0.8711 - recall: 0.8711 - val_accuracy: 0.8429 - val_loss: 1.0256 - val_precision: 0.8429 - val_recall: 0.8429 - learning_rate: 5.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8786 - loss: 0.9932 - precision: 0.8786 - recall: 0.8786 - val_accuracy: 0.8179 - val_loss: 1.0577 - val_precision: 0.8179 - val_recall: 0.8179 - learning_rate: 5.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8517 - loss: 1.0267 - precision: 0.8517 - recall: 0.8517 - val_accuracy: 0.8393 - val_loss: 1.0850 - val_precision: 0.8393 - val_recall: 0.8393 - learning_rate: 5.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8470 - loss: 1.0415 - precision: 0.8470 - recall: 0.8470 - val_accuracy: 0.8286 - val_loss: 1.0683 - val_precision: 0.8286 - val_recall: 0.8286 - learning_rate: 5.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8876 - loss: 0.9579 - precision: 0.8876 - recall: 0.8876 - val_accuracy: 0.8857 - val_loss: 0.9382 - val_precision: 0.8857 - val_recall: 0.8857 - learning_rate: 2.5000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9393 - loss: 0.8359 - precision: 0.9393 - recall: 0.9393 - val_accuracy: 0.9000 - val_loss: 0.8403 - val_precision: 0.9000 - val_recall: 0.9000 - learning_rate: 2.5000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9509 - loss: 0.7320 - precision: 0.9509 - recall: 0.9509 - val_accuracy: 0.9000 - val_loss: 0.7720 - val_precision: 0.9000 - val_recall: 0.9000 - learning_rate: 2.5000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9469 - loss: 0.6862 - precision: 0.9469 - recall: 0.9469 - val_accuracy: 0.9250 - val_loss: 0.7006 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 2.5000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9637 - loss: 0.6076 - precision: 0.9637 - recall: 0.9637 - val_accuracy: 0.9214 - val_loss: 0.6776 - val_precision: 0.9214 - val_recall: 0.9214 - learning_rate: 2.5000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9610 - loss: 0.5664 - precision: 0.9610 - recall: 0.9610 - val_accuracy: 0.9143 - val_loss: 0.6583 - val_precision: 0.9143 - val_recall: 0.9143 - learning_rate: 2.5000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9550 - loss: 0.5521 - precision: 0.9550 - recall: 0.9550 - val_accuracy: 0.9286 - val_loss: 0.6311 - val_precision: 0.9286 - val_recall: 0.9286 - learning_rate: 2.5000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9560 - loss: 0.5552 - precision: 0.9560 - recall: 0.9560 - val_accuracy: 0.9036 - val_loss: 0.6810 - val_precision: 0.9036 - val_recall: 0.9036 - learning_rate: 2.5000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9479 - loss: 0.5572 - precision: 0.9479 - recall: 0.9479 - val_accuracy: 0.8929 - val_loss: 0.6475 - val_precision: 0.8929 - val_recall: 0.8929 - learning_rate: 2.5000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9505 - loss: 0.5635 - precision: 0.9505 - recall: 0.9505 - val_accuracy: 0.8929 - val_loss: 0.6683 - val_precision: 0.8929 - val_recall: 0.8929 - learning_rate: 2.5000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9605 - loss: 0.5493 - precision: 0.9605 - recall: 0.9605 - val_accuracy: 0.8893 - val_loss: 0.6457 - val_precision: 0.8893 - val_recall: 0.8893 - learning_rate: 2.5000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9486 - loss: 0.5598 - precision: 0.9486 - recall: 0.9486 - val_accuracy: 0.9214 - val_loss: 0.6081 - val_precision: 0.9214 - val_recall: 0.9214 - learning_rate: 2.5000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9742 - loss: 0.5004 - precision: 0.9742 - recall: 0.9742 - val_accuracy: 0.9321 - val_loss: 0.5552 - val_precision: 0.9321 - val_recall: 0.9321 - learning_rate: 1.2500e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9838 - loss: 0.4544 - precision: 0.9838 - recall: 0.9838 - val_accuracy: 0.9536 - val_loss: 0.5073 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 1.2500e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.4215 - precision: 0.9890 - recall: 0.9890 - val_accuracy: 0.9393 - val_loss: 0.5014 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 1.2500e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9900 - loss: 0.3966 - precision: 0.9900 - recall: 0.9900 - val_accuracy: 0.9500 - val_loss: 0.4845 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 1.2500e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9904 - loss: 0.3676 - precision: 0.9904 - recall: 0.9904 - val_accuracy: 0.9429 - val_loss: 0.4716 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 1.2500e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.3460 - precision: 0.9955 - recall: 0.9955 - val_accuracy: 0.9357 - val_loss: 0.4716 - val_precision: 0.9357 - val_recall: 0.9357 - learning_rate: 1.2500e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.3226 - precision: 0.9986 - recall: 0.9986 - val_accuracy: 0.9464 - val_loss: 0.4253 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 1.2500e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9972 - loss: 0.3056 - precision: 0.9972 - recall: 0.9972 - val_accuracy: 0.9321 - val_loss: 0.4208 - val_precision: 0.9321 - val_recall: 0.9321 - learning_rate: 6.2500e-05
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.2966 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9429 - val_loss: 0.3992 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 6.2500e-05
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9989 - loss: 0.2863 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9429 - val_loss: 0.4153 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 6.2500e-05
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.2741 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.4037 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 6.2500e-05
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9972 - loss: 0.2692 - precision: 0.9972 - recall: 0.9972 - val_accuracy: 0.9536 - val_loss: 0.3918 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 6.2500e-05
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.2589 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.3879 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 3.1250e-05
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.2550 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9393 - val_loss: 0.3885 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 3.1250e-05
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.2498 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9321 - val_loss: 0.3963 - val_precision: 0.9321 - val_recall: 0.9321 - learning_rate: 3.1250e-05
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9963 - loss: 0.2507 - precision: 0.9963 - recall: 0.9963 - val_accuracy: 0.9321 - val_loss: 0.3901 - val_precision: 0.9321 - val_recall: 0.9321 - learning_rate: 3.1250e-05
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9992 - loss: 0.2428 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9464 - val_loss: 0.3685 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 3.1250e-05
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9600    0.9655    0.9628       174
#            1     0.9429    0.9340    0.9384       106
#
#     accuracy                         0.9536       280
#    macro avg     0.9514    0.9497    0.9506       280
# weighted avg     0.9535    0.9536    0.9535       280
#
#
# Final Metrics:
# Accuracy: 0.9536
# AUC: 0.9887

# %%
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, roc_curve, auc, accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# === 1. Data Preparation ===
scaler = StandardScaler()
X_ga_train_scaled = scaler.fit_transform(X_ga_train[:, selected_features])
X_ga_val_scaled = scaler.transform(X_ga_val[:, selected_features])

# Reshape for LSTM [samples, timesteps=1, features]
X_train = X_ga_train_scaled.reshape(X_ga_train_scaled.shape[0], 1, X_ga_train_scaled.shape[1])
X_val = X_ga_val_scaled.reshape(X_ga_val_scaled.shape[0], 1, X_ga_val_scaled.shape[1])

# Compute class weights
y_labels = np.argmax(y_ga_train, axis=1)
weights = class_weight.compute_class_weight(class_weight='balanced',
                                             classes=np.unique(y_labels),
                                             y=y_labels)
class_weights = dict(enumerate(weights))

# === 2. BiLSTM Model Architecture ===
def build_bilstm_model(input_shape):
    inputs = Input(shape=input_shape)
   
    # BiLSTM Layer with regularization
    x = Bidirectional(LSTM(64,
                           return_sequences=False,
                           kernel_regularizer=l2(0.01),
                           recurrent_regularizer=l2(0.01)))(inputs)
    x = Dropout(0.3)(x)
    x = BatchNormalization()(x)

    # Dense layer
    x = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = Dropout(0.2)(x)

    # Output layer
    outputs = Dense(2, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    return model

model = build_bilstm_model((1, X_train.shape[2]))

# === 3. Compile Model ===
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, clipvalue=0.5)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy',
                       tf.keras.metrics.Precision(name='precision'),
                       tf.keras.metrics.Recall(name='recall')])

# === 4. Callbacks ===
callbacks = [
    EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True),
    ModelCheckpoint('best_bilstm_model.keras', save_best_only=True, monitor='val_accuracy'),
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=6, min_lr=1e-6)
]

# === 5. Train Model ===
history = model.fit(
    X_train, y_ga_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_val, y_ga_val),
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=1
)

# === 6. Evaluation ===
val_probs = model.predict(X_val)
val_preds = np.argmax(val_probs, axis=1)
y_true = np.argmax(y_ga_val, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, val_preds, digits=4))

accuracy = accuracy_score(y_true, val_preds)
fpr, tpr, _ = roc_curve(y_true, val_probs[:, 1])
roc_auc = auc(fpr, tpr)

print(f"\nFinal Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"AUC: {roc_auc:.4f}")

# === 7. ROC Curve ===
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# === 8. Learning Curves ===
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - accuracy: 0.5567 - loss: 10.5856 - precision: 0.5567 - recall: 0.5567 - val_accuracy: 0.7250 - val_loss: 6.5022 - val_precision: 0.7250 - val_recall: 0.7250 - learning_rate: 0.0010
# Epoch 2/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6785 - loss: 5.7640 - precision: 0.6785 - recall: 0.6785 - val_accuracy: 0.7679 - val_loss: 4.0154 - val_precision: 0.7679 - val_recall: 0.7679 - learning_rate: 0.0010
# Epoch 3/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7312 - loss: 3.7290 - precision: 0.7312 - recall: 0.7312 - val_accuracy: 0.7571 - val_loss: 3.0592 - val_precision: 0.7571 - val_recall: 0.7571 - learning_rate: 0.0010
# Epoch 4/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7167 - loss: 2.9631 - precision: 0.7167 - recall: 0.7167 - val_accuracy: 0.7821 - val_loss: 2.6226 - val_precision: 0.7821 - val_recall: 0.7821 - learning_rate: 0.0010
# Epoch 5/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7434 - loss: 2.5901 - precision: 0.7434 - recall: 0.7434 - val_accuracy: 0.7929 - val_loss: 2.3982 - val_precision: 0.7929 - val_recall: 0.7929 - learning_rate: 0.0010
# Epoch 6/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7420 - loss: 2.4011 - precision: 0.7420 - recall: 0.7420 - val_accuracy: 0.7750 - val_loss: 2.2792 - val_precision: 0.7750 - val_recall: 0.7750 - learning_rate: 0.0010
# Epoch 7/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7515 - loss: 2.3056 - precision: 0.7515 - recall: 0.7515 - val_accuracy: 0.7643 - val_loss: 2.2147 - val_precision: 0.7643 - val_recall: 0.7643 - learning_rate: 0.0010
# Epoch 8/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7488 - loss: 2.2724 - precision: 0.7488 - recall: 0.7488 - val_accuracy: 0.8107 - val_loss: 2.1515 - val_precision: 0.8107 - val_recall: 0.8107 - learning_rate: 0.0010
# Epoch 9/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7709 - loss: 2.1602 - precision: 0.7709 - recall: 0.7709 - val_accuracy: 0.7821 - val_loss: 2.0386 - val_precision: 0.7821 - val_recall: 0.7821 - learning_rate: 0.0010
# Epoch 10/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7823 - loss: 2.0431 - precision: 0.7823 - recall: 0.7823 - val_accuracy: 0.7679 - val_loss: 2.0172 - val_precision: 0.7679 - val_recall: 0.7679 - learning_rate: 0.0010
# Epoch 11/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7420 - loss: 2.0868 - precision: 0.7420 - recall: 0.7420 - val_accuracy: 0.7714 - val_loss: 2.0424 - val_precision: 0.7714 - val_recall: 0.7714 - learning_rate: 0.0010
# Epoch 12/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7666 - loss: 2.0435 - precision: 0.7666 - recall: 0.7666 - val_accuracy: 0.7286 - val_loss: 2.0611 - val_precision: 0.7286 - val_recall: 0.7286 - learning_rate: 0.0010
# Epoch 13/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7431 - loss: 2.0716 - precision: 0.7431 - recall: 0.7431 - val_accuracy: 0.7714 - val_loss: 2.0961 - val_precision: 0.7714 - val_recall: 0.7714 - learning_rate: 0.0010
# Epoch 14/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7495 - loss: 2.1127 - precision: 0.7495 - recall: 0.7495 - val_accuracy: 0.7286 - val_loss: 2.1199 - val_precision: 0.7286 - val_recall: 0.7286 - learning_rate: 0.0010
# Epoch 15/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7533 - loss: 2.0652 - precision: 0.7533 - recall: 0.7533 - val_accuracy: 0.8250 - val_loss: 1.7535 - val_precision: 0.8250 - val_recall: 0.8250 - learning_rate: 5.0000e-04
# Epoch 16/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8372 - loss: 1.6195 - precision: 0.8372 - recall: 0.8372 - val_accuracy: 0.8321 - val_loss: 1.4261 - val_precision: 0.8321 - val_recall: 0.8321 - learning_rate: 5.0000e-04
# Epoch 17/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8699 - loss: 1.3194 - precision: 0.8699 - recall: 0.8699 - val_accuracy: 0.8429 - val_loss: 1.2407 - val_precision: 0.8429 - val_recall: 0.8429 - learning_rate: 5.0000e-04
# Epoch 18/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8910 - loss: 1.1829 - precision: 0.8910 - recall: 0.8910 - val_accuracy: 0.8464 - val_loss: 1.2193 - val_precision: 0.8464 - val_recall: 0.8464 - learning_rate: 5.0000e-04
# Epoch 19/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8853 - loss: 1.1354 - precision: 0.8853 - recall: 0.8853 - val_accuracy: 0.8357 - val_loss: 1.2113 - val_precision: 0.8357 - val_recall: 0.8357 - learning_rate: 5.0000e-04
# Epoch 20/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8913 - loss: 1.1312 - precision: 0.8913 - recall: 0.8913 - val_accuracy: 0.8536 - val_loss: 1.2077 - val_precision: 0.8536 - val_recall: 0.8536 - learning_rate: 5.0000e-04
# Epoch 21/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8704 - loss: 1.2103 - precision: 0.8704 - recall: 0.8704 - val_accuracy: 0.8286 - val_loss: 1.3165 - val_precision: 0.8286 - val_recall: 0.8286 - learning_rate: 5.0000e-04
# Epoch 22/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8707 - loss: 1.2402 - precision: 0.8707 - recall: 0.8707 - val_accuracy: 0.8036 - val_loss: 1.2902 - val_precision: 0.8036 - val_recall: 0.8036 - learning_rate: 5.0000e-04
# Epoch 23/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8492 - loss: 1.2666 - precision: 0.8492 - recall: 0.8492 - val_accuracy: 0.8500 - val_loss: 1.2699 - val_precision: 0.8500 - val_recall: 0.8500 - learning_rate: 5.0000e-04
# Epoch 24/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8725 - loss: 1.2469 - precision: 0.8725 - recall: 0.8725 - val_accuracy: 0.8536 - val_loss: 1.2505 - val_precision: 0.8536 - val_recall: 0.8536 - learning_rate: 5.0000e-04
# Epoch 25/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8599 - loss: 1.2421 - precision: 0.8599 - recall: 0.8599 - val_accuracy: 0.8286 - val_loss: 1.2670 - val_precision: 0.8286 - val_recall: 0.8286 - learning_rate: 5.0000e-04
# Epoch 26/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8758 - loss: 1.2117 - precision: 0.8758 - recall: 0.8758 - val_accuracy: 0.8357 - val_loss: 1.2057 - val_precision: 0.8357 - val_recall: 0.8357 - learning_rate: 5.0000e-04
# Epoch 27/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8853 - loss: 1.1463 - precision: 0.8853 - recall: 0.8853 - val_accuracy: 0.8821 - val_loss: 1.0659 - val_precision: 0.8821 - val_recall: 0.8821 - learning_rate: 2.5000e-04
# Epoch 28/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9311 - loss: 0.9623 - precision: 0.9311 - recall: 0.9311 - val_accuracy: 0.9179 - val_loss: 0.9096 - val_precision: 0.9179 - val_recall: 0.9179 - learning_rate: 2.5000e-04
# Epoch 29/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9461 - loss: 0.8268 - precision: 0.9461 - recall: 0.9461 - val_accuracy: 0.9214 - val_loss: 0.8163 - val_precision: 0.9214 - val_recall: 0.9214 - learning_rate: 2.5000e-04
# Epoch 30/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9561 - loss: 0.7261 - precision: 0.9561 - recall: 0.9561 - val_accuracy: 0.9179 - val_loss: 0.7693 - val_precision: 0.9179 - val_recall: 0.9179 - learning_rate: 2.5000e-04
# Epoch 31/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9664 - loss: 0.6411 - precision: 0.9664 - recall: 0.9664 - val_accuracy: 0.9250 - val_loss: 0.6882 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 2.5000e-04
# Epoch 32/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9737 - loss: 0.5738 - precision: 0.9737 - recall: 0.9737 - val_accuracy: 0.9250 - val_loss: 0.6566 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 2.5000e-04
# Epoch 33/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9797 - loss: 0.5154 - precision: 0.9797 - recall: 0.9797 - val_accuracy: 0.9179 - val_loss: 0.5890 - val_precision: 0.9179 - val_recall: 0.9179 - learning_rate: 2.5000e-04
# Epoch 34/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9704 - loss: 0.4873 - precision: 0.9704 - recall: 0.9704 - val_accuracy: 0.9250 - val_loss: 0.6198 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 2.5000e-04
# Epoch 35/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9538 - loss: 0.5335 - precision: 0.9538 - recall: 0.9538 - val_accuracy: 0.9000 - val_loss: 0.6540 - val_precision: 0.9000 - val_recall: 0.9000 - learning_rate: 2.5000e-04
# Epoch 36/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9489 - loss: 0.5645 - precision: 0.9489 - recall: 0.9489 - val_accuracy: 0.8821 - val_loss: 0.6874 - val_precision: 0.8821 - val_recall: 0.8821 - learning_rate: 2.5000e-04
# Epoch 37/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9641 - loss: 0.5388 - precision: 0.9641 - recall: 0.9641 - val_accuracy: 0.8964 - val_loss: 0.6642 - val_precision: 0.8964 - val_recall: 0.8964 - learning_rate: 2.5000e-04
# Epoch 38/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9681 - loss: 0.5359 - precision: 0.9681 - recall: 0.9681 - val_accuracy: 0.9143 - val_loss: 0.5973 - val_precision: 0.9143 - val_recall: 0.9143 - learning_rate: 1.2500e-04
# Epoch 39/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9717 - loss: 0.4624 - precision: 0.9717 - recall: 0.9717 - val_accuracy: 0.9250 - val_loss: 0.5515 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 1.2500e-04
# Epoch 40/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.4154 - precision: 0.9906 - recall: 0.9906 - val_accuracy: 0.9179 - val_loss: 0.4935 - val_precision: 0.9179 - val_recall: 0.9179 - learning_rate: 1.2500e-04
# Epoch 41/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9918 - loss: 0.3809 - precision: 0.9918 - recall: 0.9918 - val_accuracy: 0.9321 - val_loss: 0.4696 - val_precision: 0.9321 - val_recall: 0.9321 - learning_rate: 1.2500e-04
# Epoch 42/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9931 - loss: 0.3489 - precision: 0.9931 - recall: 0.9931 - val_accuracy: 0.9357 - val_loss: 0.4472 - val_precision: 0.9357 - val_recall: 0.9357 - learning_rate: 1.2500e-04
# Epoch 43/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9871 - loss: 0.3318 - precision: 0.9871 - recall: 0.9871 - val_accuracy: 0.9286 - val_loss: 0.4242 - val_precision: 0.9286 - val_recall: 0.9286 - learning_rate: 1.2500e-04
# Epoch 44/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9991 - loss: 0.2963 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9393 - val_loss: 0.4200 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 1.2500e-04
# Epoch 45/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9956 - loss: 0.2761 - precision: 0.9956 - recall: 0.9956 - val_accuracy: 0.9250 - val_loss: 0.3939 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 1.2500e-04
# Epoch 46/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9970 - loss: 0.2568 - precision: 0.9970 - recall: 0.9970 - val_accuracy: 0.9250 - val_loss: 0.3878 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 1.2500e-04
# Epoch 47/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.2506 - precision: 0.9969 - recall: 0.9969 - val_accuracy: 0.9250 - val_loss: 0.3785 - val_precision: 0.9250 - val_recall: 0.9250 - learning_rate: 1.2500e-04
# Epoch 48/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9966 - loss: 0.2423 - precision: 0.9966 - recall: 0.9966 - val_accuracy: 0.9357 - val_loss: 0.3591 - val_precision: 0.9357 - val_recall: 0.9357 - learning_rate: 1.2500e-04
# Epoch 49/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9945 - loss: 0.2494 - precision: 0.9945 - recall: 0.9945 - val_accuracy: 0.9214 - val_loss: 0.4263 - val_precision: 0.9214 - val_recall: 0.9214 - learning_rate: 1.2500e-04
# Epoch 50/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9787 - loss: 0.2808 - precision: 0.9787 - recall: 0.9787 - val_accuracy: 0.9000 - val_loss: 0.4558 - val_precision: 0.9000 - val_recall: 0.9000 - learning_rate: 1.2500e-04
# Epoch 51/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9753 - loss: 0.2956 - precision: 0.9753 - recall: 0.9753 - val_accuracy: 0.9286 - val_loss: 0.3996 - val_precision: 0.9286 - val_recall: 0.9286 - learning_rate: 6.2500e-05
# Epoch 52/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9970 - loss: 0.2549 - precision: 0.9970 - recall: 0.9970 - val_accuracy: 0.9286 - val_loss: 0.3770 - val_precision: 0.9286 - val_recall: 0.9286 - learning_rate: 6.2500e-05
# Epoch 53/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9919 - loss: 0.2456 - precision: 0.9919 - recall: 0.9919 - val_accuracy: 0.9393 - val_loss: 0.3832 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 6.2500e-05
# Epoch 54/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 0.2289 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.3479 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 6.2500e-05
# Epoch 55/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9990 - loss: 0.2180 - precision: 0.9990 - recall: 0.9990 - val_accuracy: 0.9393 - val_loss: 0.3461 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 6.2500e-05
# Epoch 56/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9992 - loss: 0.2049 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9393 - val_loss: 0.3423 - val_precision: 0.9393 - val_recall: 0.9393 - learning_rate: 6.2500e-05
# Epoch 57/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1983 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9429 - val_loss: 0.3420 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 6.2500e-05
# Epoch 58/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - loss: 0.1961 - precision: 0.9964 - recall: 0.9964 - val_accuracy: 0.9357 - val_loss: 0.3556 - val_precision: 0.9357 - val_recall: 0.9357 - learning_rate: 6.2500e-05
# Epoch 59/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9979 - loss: 0.1877 - precision: 0.9979 - recall: 0.9979 - val_accuracy: 0.9464 - val_loss: 0.3265 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 6.2500e-05
# Epoch 60/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9999 - loss: 0.1821 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9429 - val_loss: 0.3635 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 6.2500e-05
# Epoch 61/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1746 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.3113 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 3.1250e-05
# Epoch 62/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1688 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9357 - val_loss: 0.2993 - val_precision: 0.9357 - val_recall: 0.9357 - learning_rate: 3.1250e-05
# Epoch 63/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1650 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2882 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 3.1250e-05
# Epoch 64/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1613 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9429 - val_loss: 0.2862 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 3.1250e-05
# Epoch 65/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 0.1580 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2834 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 3.1250e-05
# Epoch 66/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1549 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9429 - val_loss: 0.2736 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 3.1250e-05
# Epoch 67/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1519 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2651 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 3.1250e-05
# Epoch 68/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1495 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2658 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 3.1250e-05
# Epoch 69/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1473 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2682 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 3.1250e-05
# Epoch 70/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1436 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2722 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 3.1250e-05
# Epoch 71/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1399 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2575 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 3.1250e-05
# Epoch 72/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1375 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2564 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 1.5625e-05
# Epoch 73/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1364 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9429 - val_loss: 0.2612 - val_precision: 0.9429 - val_recall: 0.9429 - learning_rate: 1.5625e-05
# Epoch 74/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1366 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2510 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 1.5625e-05
# Epoch 75/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1342 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2673 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 1.5625e-05
# Epoch 76/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1352 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2532 - val_precision: 0.9464 - val_recall: 0.9464 - learning_rate: 1.5625e-05
# Epoch 77/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1308 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2473 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 1.5625e-05
# Epoch 78/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.1298 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2481 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 7.8125e-06
# Epoch 79/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1292 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2446 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 7.8125e-06
# Epoch 80/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9998 - loss: 0.1283 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9571 - val_loss: 0.2436 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 7.8125e-06
# Epoch 81/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1280 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2466 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 7.8125e-06
# Epoch 82/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1272 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2426 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 7.8125e-06
# Epoch 83/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1264 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2421 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 7.8125e-06
# Epoch 84/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1262 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9500 - val_loss: 0.2440 - val_precision: 0.9500 - val_recall: 0.9500 - learning_rate: 7.8125e-06
# Epoch 85/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1258 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2414 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 3.9063e-06
# Epoch 86/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.1248 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2383 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 87/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1242 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2376 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 88/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1240 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2360 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 89/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1236 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2346 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 90/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1226 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2334 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 91/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1225 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2347 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 92/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1233 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2373 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 3.9063e-06
# Epoch 93/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1224 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2363 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.9531e-06
# Epoch 94/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1225 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2360 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.9531e-06
# Epoch 95/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1218 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2364 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.9531e-06
# Epoch 96/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1208 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2362 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.9531e-06
# Epoch 97/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1205 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2366 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.9531e-06
# Epoch 98/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.1205 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9643 - val_loss: 0.2365 - val_precision: 0.9643 - val_recall: 0.9643 - learning_rate: 1.9531e-06
# Epoch 99/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1214 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2365 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.9531e-06
# Epoch 100/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1210 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2383 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.9531e-06
# Epoch 101/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1205 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9643 - val_loss: 0.2379 - val_precision: 0.9643 - val_recall: 0.9643 - learning_rate: 1.9531e-06
# Epoch 102/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1219 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9536 - val_loss: 0.2378 - val_precision: 0.9536 - val_recall: 0.9536 - learning_rate: 1.9531e-06
# Epoch 103/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1198 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2375 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.9531e-06
# Epoch 104/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1196 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2365 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.9531e-06
# Epoch 105/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1208 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2376 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.0000e-06
# Epoch 106/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1199 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2361 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 107/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1211 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2338 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.0000e-06
# Epoch 108/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1204 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2347 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 109/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1191 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2347 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.0000e-06
# Epoch 110/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1184 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2350 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.0000e-06
# Epoch 111/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1207 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2335 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 112/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1190 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2332 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 113/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1182 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2327 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 114/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1182 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2332 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 115/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1180 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2339 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 116/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1180 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2344 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 117/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1184 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9607 - val_loss: 0.2344 - val_precision: 0.9607 - val_recall: 0.9607 - learning_rate: 1.0000e-06
# Epoch 118/500
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1186 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9571 - val_loss: 0.2359 - val_precision: 0.9571 - val_recall: 0.9571 - learning_rate: 1.0000e-06
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9713    0.9713    0.9713       174
#            1     0.9528    0.9528    0.9528       106
#
#     accuracy                         0.9643       280
#    macro avg     0.9620    0.9620    0.9620       280
# weighted avg     0.9643    0.9643    0.9643       280
#
#
# Final Metrics:
# Accuracy: 0.9643
# AUC: 0.9910
